# %%
from environment import *

# %%
grid_range = (-1.2, 1.2)
obstacle_range = (-0.7, 0.7)
start_point = (-1, -1)
end_point = (1, 1)
obstacle_points = 15
eta = 0.9
grid_resolution = 500
prng_seed = 1337

env = EnvironmentDescriptor(
    grid_range,
    obstacle_range,
    start_point,
    end_point,
    obstacle_points,
    eta,
    grid_resolution,
    prng_seed
)
env.plot_environment()
